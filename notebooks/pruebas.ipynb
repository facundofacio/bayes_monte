# %%
import warnings

import arviz as az
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import bambi as bmb

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
datos = pd.read_csv("Transectas.csv")
datos = datos.query("Pastoreo == 'Continuo'")

# %%
cob = datos[["Fecha", "Bosque", "Repet", "Transecta", "puntotransecta", "Cob"]]
# haz lower para cada titulo de columna
cob.columns = [col.lower() for col in cob.columns]
cob.head()
# Out:
#       fecha    bosque  repet transecta  puntotransecta    cob
# 22  2018-02  Arbustal      1   AR CO 1               1  0.000
# 23  2018-02  Arbustal      1   AR CO 1               2  0.137
# 24  2018-02  Arbustal      1   AR CO 1               3  0.498
# 25  2018-02  Arbustal      1   AR CO 1               4  0.785
# 26  2018-02  Arbustal      1   AR CO 1               5  0.382
